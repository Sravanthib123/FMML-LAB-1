# %% [markdown]
# <a href="https://colab.research.google.com/github/Sravanthib123/FMML-LAB-1/blob/main/Module_8_Lab__3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-28 06:06:17--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   110MB/s    in 0.6s
#
# 2024-03-28 06:06:19 (110 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 12159  1709.05418v1  We present a technique for efficiently synthes...    cs
# 4460   1712.06715v1  Geometric variations of objects, which do not ...  stat
# 19200   1304.2353v1  This paper addresses the problem of resolving ...    cs
# 16948  1707.06012v2  NMT systems have problems with large vocabular...    cs
# 14495  cs/0105037v1  We present a probabilistic model that uses bot...    cs
# ...             ...                                                ...   ...
# 33284   0902.1037v2  In this work we deal with the optimal design a...    cs
# 9418   1707.01195v3  Various measures can be used to estimate bias ...  stat
# 22674  1704.01871v1  Cluster analysis of very high dimensional data...  stat
# 11040   1311.6976v2  In online advertising, display ads are increas...  stat
# 17843  1803.06456v1  We propose two models for a special case of au...    cs
#
#                                                    title  year  \
# 12159  Deep Scattering: Rendering Atmospheric Clouds ...  2017
# 4460                              Deformable Classifiers  2017
# 19200                Truth Maintenance Under Uncertainty  2013
# 16948  Modeling Target-Side Inflection in Neural Mach...  2017
# 14495  Integrating Prosodic and Lexical Cues for Auto...  2001
# ...                                                  ...   ...
# 33284  Optimal design and optimal control of structur...  2009
# 9418   The impossibility of "fairness": a generalized...  2017
# 22674  Massive Data Clustering in Moderate Dimensions...  2017
# 11040  Dimensionality reduction for click-through rat...  2013
# 17843  Experiments with Neural Networks for Small and...  2018
#
#                                                 keywords
# 12159  [technique, efficiently, synthesizing, atmosph...
# 4460   [geometric, variations, challenge, recognition...
# 19200  [addresses, resolving, uncertainty, developed,...
# 16948  [vocabulary, effective, generalization, vocabu...
# 14495  [probabilistic, automatic, segmentation, topic...
# ...                                                  ...
# 33284  [structures, undergoing, rotations, correspond...
# 9418   [unfairness, predictor, established, incompati...
# 22674  [dimensional, properties, dimensionality, info...
# 11040  [advertising, increasingly, advertiser, constr...
# 17843  [authorship, verification, investigate, docume...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 12159    [technique, efficiently, synthesizing, atmosph...
# 4460     [geometric, variations, challenge, recognition...
# 19200    [addresses, resolving, uncertainty, developed,...
# 16948    [vocabulary, effective, generalization, vocabu...
# 14495    [probabilistic, automatic, segmentation, topic...
#                                ...
# 11063    [describes, recognition, electrochemical, impe...
# 21659    [multivariate, conditions, generalized, canoni...
# 14237    [applications, detecting, anomalies, differenc...
# 7540     [parameters, methylation, algorithm, computati...
# 34455    [background, guidelines, recommendations, avai...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8679 words.
# Out of those 4492 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="a7ded833-b896-47eb-a39a-c01447cc8226" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a7ded833-b896-47eb-a39a-c01447cc8226")) {                    Plotly.newPlot(                        "a7ded833-b896-47eb-a39a-c01447cc8226",                        [{"x":["combination","reference","synthesizing","observation","integration","indistinguishable","production","atmospheric","performance","whiteness","differently","synthesizes","descriptor","represents","applications","challenging","directional","predicting","exemplars","configuration","progressively","connections","interactively","stability","scattering","characteristic","technique","transport","efficiently","hierarchical","diffusion","rendering","coefficients","implementation","simulating","distribution","classifier","classification","transformation","mechanism","multilayer","classifiers","computation","separately","geometric","downstream","parameters","variables","recognition","competitive","challenge","variations","optimizing","deformable","framework","perceptrons","introduced","transformations","instantiation","alternates","discussed","maintenance","heuristics","addresses","limitations","fundamental","resolving","developed","reformulates","uncertainty","effective","deterministic","morphologically","introduce","inflectional","translation","vocabulary","obtaining","phenomena","information","morphological","improvements","generation","inflection","improvement","languages","scenarios","generalization","furthermore","broadcast","segmentation","extracted","evaluation","topically","combining","reduction","knowledge","automatically","integrating","waveforms","significant","automatic","recognizer","probabilistic","assumption","unsupervised","parameter","recommender","inflexible","correlation","including","clustering","approaches","experiments","maintaining","dependent","nonparametric","specified","flexibility","comparing","corresponding","respective","appropriate","dimension","typically","processes","factorization","consequence","correlated","optimized","bivariate","factorize","nonnegative","synthetic","dimensionality","associated","traditional","formalized","comparison","difficult","constantly","intuitively","techniques","numerical","available","throughout","propagation","benchmark","importance","describing","supervised","algorithm","therefore","effectively","necessarily","formalism","definition","advantages","experimentation","application","especially","remaining","iteratively","practical","extensions","summarization","representation","overfitting","monocular","algorithms","overcomplete","dictionaries","unreliable","activities","estimation","experimental","estimates","posterior","simultaneously","dictionary","auxiliary","constrained","specifically","autoencoders","variational","unlabeled","disentangling","representations","processing","demonstrate","literature","disentanglement","positively","experimentally","direction","variation","contribute","generalized","piecewise","tibshirani"],"y":[117,50,7,74,43,6,26,4,946,1,10,4,31,51,461,262,17,78,3,25,10,48,6,42,11,29,243,5,155,118,18,9,35,145,9,208,142,479,61,78,23,113,154,30,71,12,239,126,384,114,128,60,43,12,535,8,138,37,3,2,61,7,38,46,55,78,6,210,1,94,269,35,8,337,3,119,42,32,32,689,30,110,140,3,133,105,104,118,165,9,222,109,263,2,109,100,324,173,36,3,244,192,7,160,68,149,120,14,1,69,258,135,431,642,33,66,21,32,33,78,141,14,67,75,104,89,56,23,31,45,3,1,10,150,51,87,168,10,125,132,5,14,386,89,308,13,66,216,75,30,186,826,154,131,19,15,41,88,15,251,120,30,42,135,41,34,384,26,20,565,5,21,8,34,175,378,77,38,111,64,17,67,181,17,43,46,4,235,315,568,123,1,6,63,72,56,31,83,13,1],"type":"bar"},{"x":["combination","reference","synthesizing ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4492,), (4492, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8025

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.4230769230769231);'>Exploring</span> <span style=''>Content</span> <span style=''>based</span> <span style=''>Artwork</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Recommendation</span> <span style=''>with</span> <span style=''>Metadata</span> <span style=''>and</span> <span style=''>Visual</span> <span style=''>Features</span> <br/><br/><span style=''>Compared</span> <span style=''>to</span> <span style=''>other</span> <span style=''>areas</span> <span style=''>artwork</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>recommendation</span> <span style=''>has</span> <span style=''>received</span> <span style=''>little</span> <span style='background-color:rgba(0, 255, 0, 0.382716049382716);'>attention</span> <span style=''>despite</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>continuous</span> <span style=''>growth</span> <span style=''>of</span> <span style=''>the</span> <span style=''>artwork</span> <span style=''>market</span> <span style=''>Previous</span> <span style=''>research</span> <span style=''>has</span> <span style=''>relied</span> <span style=''>on</span> <span style=''>ratings</span> <span style=''>and</span> <span style=''>metadata</span> <span style=''>to</span> <span style=''>make</span> <span style=''>artwork</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>recommendations</span> <span style=''>as</span> <span style=''>well</span> <span style=''>as</span> <span style=''>visual</span> <span style=''>features</span> <span style='background-color:rgba(0, 255, 0, 0.6515151515151515);'>extracted</span> <span style=''>with</span> <span style=''>deep</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>(DNN)</span> <span style=''>However</span> <span style=''>these</span> <span style=''>features</span> <span style=''>have</span> <span style=''>no</span> <span style=''>direct</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interpretation</span> <span style=''>to</span> <span style=''>explicit</span> <span style=''>visual</span> <span style=''>features</span> <span style=''>(eg</span> <span style='background-color:rgba(0, 255, 0, 0.8);'>brightness</span> <span style=''>texture)</span> <span style=''>which</span> <span style=''>might</span> <span style=''>hinder</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>explainability</span> <span style=''>and</span> <span style=''>user</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>acceptance</span> <span style=''>In</span> <span style=''>this</span> <span style=''>work</span> <span style=''>we</span> <span style=''>study</span> <span style=''>the</span> <span style=''>impact</span> <span style=''>of</span> <span style=''>artwork</span> <span style=''>metadata</span> <span style=''>as</span> <span style=''>well</span> <span style=''>as</span> <span style=''>visual</span> <span style=''>features</span> <span style=''>(DNN</span> <span style=''>based</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>attractiveness</span> <span style=''>based)</span> <span style=''>for</span> <span style=''>physical</span> <span style=''>artwork</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>recommendation</span> <span style=''>using</span> <span style=''>images</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>transaction</span> <span style=''>data</span> <span style=''>from</span> <span style=''>the</span> <span style=''>UGallery</span> <span style=''>online</span> <span style=''>artwork</span> <span style=''>store</span> <span style=''>Our</span> <span style=''>results</span> <span style=''>indicate</span> <span style=''>that</span> <span style=''>(i)</span> <span style=''>visual</span> <span style=''>features</span> <span style=''>perform</span> <span style=''>better</span> <span style=''>than</span> <span style=''>manually</ ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Probabilistic</span> <span style=''>Matrix</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Factorization</span> <span style=''>A</span> <span style=''>User</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Frequency</span> <span style=''>Analysis</span> <br/><br/><span style=''>Matrix</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>factorization</span> <span style=''>(MF)</span> <span style=''>has</span> <span style=''>become</span> <span style=''>a</span> <span style=''>common</span> <span style=''>approach</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>collaborative</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>filtering</span> <span style=''>due</span> <span style=''>to</span> <span style=''>ease</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>implementation</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>scalability</span> <span style=''>to</span> <span style=''>large</span> <span style=''>data</span> <span style=''>sets</span> <span style=''>Two</span> <span style=''>existing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>drawbacks</span> <span style=''>of</span> <span style=''>the</span> <span style=''>basic</span> <span style=''>model</span> <span style=''>is</span> <span style=''>that</span> <span style=''>it</span> <span style=''>does</span> <span style=''>not</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>incorporate</span> <span style=''>side</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>on</span> <span style=''>either</span> <span style=''>users</span> <span style=''>or</span> <span style=''>items</span> <span style=''>and</span> <span style=''>assumes</span> <span style=''>a</span> <span style=''>common</span> <span style=''>variance</span> <span style=''>for</span> <span style=''>all</span> <span style=''>users</span> <span style=''>We</span> <span style=''>extend</span> <span style=''>the</span> <span style=''>work</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>constrained</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilistic</span> <span style=''>matrix</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>factorization</span> <span style=''>by</span> <span style=''>deriving</span> <span style=''>the</span> <span style=''>Gibbs</span> <span style=''>updates</span> <span style=''>for</span> <span style=''>the</span> <span style=''>side</span> <span style=''>feature</span> <span style=''>vectors</span> <span style=''>for</span> <span style=''>items</span> <span style=''>(Salakhutdinov</span> <span style=''>and</span> <span style=''>Minh</span> <span style=''>2008)</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>this</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>treatment</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>constrained</span> <span style=''>PMF</span> <span style=''>model</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>outperforms</span> <span style=''>simple</span> <span style=''>MAP</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>We</span> <span style=''>also</span> <span style=''>consider</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>extensions</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>heteroskedastic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>precision</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduced</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>liter ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3053892215568863);'>Convergence</span> <span style=''>of</span> <span style=''>Bayesian</span> <span style=''>Control</span> <span style=''>Rule</span> <br/><br/><span style=''>Recently</span> <span style=''>new</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approaches</span> <span style=''>to</span> <span style=''>adaptive</span> <span style=''>control</span> <span style=''>have</span> <span style=''>sought</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reformulate</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>as</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>minimization</span> <span style=''>of</span> <span style=''>a</span> <span style=''>relative</span> <span style=''>entropy</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>criterion</span> <span style=''>to</span> <span style=''>obtain</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>tractable</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>solutions</span> <span style=''>In</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>particular</span> <span style=''>it</span> <span style=''>has</span> <span style=''>been</span> <span style=''>shown</span> <span style=''>that</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>minimizing</span> <span style=''>the</span> <span style=''>expected</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>deviation</span> <span style=''>from</span> <span style=''>the</span> <span style=''>causal</span> <span style=''>input</span> <span style=''>output</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dependencies</span> <span style=''>of</span> <span style=''>the</span> <span style=''>true</span> <span style=''>plant</span> <span style=''>leads</span> <span style=''>to</span> <span style=''>a</span> <span style=''>new</span> <span style='background-color:rgba(0, 255, 0, 0.3440860215053763);'>promising</span> <span style='background-color:rgba(255, 0, 0, 0.44235924932975873);'>stochastic</span> <span style=''>control</span> <span style=''>rule</span> <span style=''>called</span> <span style=''>the</span> <span style=''>Bayesian</span> <span style=''>control</span> <span style=''>rule</span> <span style=''>This</span> <span style=''>work</span> <span style=''>proves</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3053892215568863);'>convergence</span> <span style=''>of</span> <span style=''>the</span> <span style=''>Bayesian</span> <span style=''>control</span> <span style=''>rule</span> <span style=''>under</span> <span style=''>two</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sufficient</span> <span style='background-color:rgba(255, 0, 0, 0.3125);'>assumptions</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>boundedness</span> <span style=''>which</span> <span style=''>is</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3333333333333334);'>ergodicity</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>condition</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>consistency</span> <span style=''>which</span> <span style=''>is</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>instantiation</span> <span style=''>of</span> <span style=''>the</span> <span style=''>sure</span> <span style=''>thing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>principle</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Out</span> <span style=''>of</span> <span style=''>Sample</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Extension</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Dimensionality</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Reduction</span> <span style=''>of</span> <span style=''>Noisy</span> <span style=''>Time</span> <span style=''>Series</span> <br/><br/><span style=''>This</span> <span style=''>paper</span> <span style=''>proposes</span> <span style=''>an</span> <span style=''>out</span> <span style=''>of</span> <span style=''>sample</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>extension</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>for</span> <span style=''>a</span> <span style=''>global</span> <span style=''>manifold</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>(Isomap)</span> <span style=''>that</span> <span style=''>uses</span> <span style=''>temporal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>in</span> <span style=''>out</span> <span style=''>of</span> <span style=''>sample</span> <span style=''>points</span> <span style=''>in</span> <span style=''>order</span> <span style=''>to</span> <span style=''>make</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>embedding</span> <span style=''>more</span> <span style=''>robust</span> <span style=''>to</span> <span style=''>noise</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>artifacts</span> <span style=''>Given</span> <span style=''>a</span> <span style=''>set</span> <span style=''>of</span> <span style=''>noise</span> <span style=''>free</span> <span style=''>training</span> <span style=''>data</span> <span style=''>and</span> <span style=''>its</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>embedding</span> <span style=''>the</span> <span style=''>proposed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>extends</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>embedding</span> <span style=''>for</span> <span style=''>a</span> <span style=''>noisy</span> <span style=''>time</span> <span style=''>series</span> <span style=''>This</span> <span style=''>is</span> <span style=''>achieved</span> <span style=''>by</span> <span style=''>adding</span> <span style=''>a</span> <span style=''>spatio</span> <span style=''>temporal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>compactness</span> <span style=''>term</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>objective</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>embedding</span> <span style=''>To</span> <span style=''>the</span> <span style=''>best</span> <span style=''>of</span> <span style=''>our</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>knowledge</span> <span style=''>this</span> <span style=''>is</span> <span style=''>the</span> <span style=''>first</span> <span style=''>method</span> <span style=''>for</span> <span style=''>out</span> <span style=''>of</span> <span style=''>sample</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>extension</span> <span style=''>of</span> <span style=''>manifold</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>embeddings</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>leverages</span> <span style=''>timing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>available</span> <span style=''>for</span> ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	experimental (0.13475935828877006)
# 	representation (0.13689839572192514)
# 	architecture (0.0855614973262032)
# 	information (0.24563279857397505)
# 	processing (0.11229946524064172)
# 	segmentation (0.07914438502673797)
# 	convolutional (0.12156862745098039)
# 	different (0.2663101604278075)
# 	detection (0.13975044563279856)
# 	recognition (0.13689839572192514)
#
# Some Statistics words are:
# 	statistical (0.15037593984962405)
# 	variables (0.1393483709273183)
# 	stochastic (0.13483709273182956)
# 	theoretical (0.15037593984962405)
# 	algorithm (0.4)
# 	estimation (0.1774436090225564)
# 	inference (0.19398496240601504)
# 	distribution (0.19398496240601504)
# 	dimensional (0.19097744360902255)
# 	regression (0.18145363408521303)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="eb9106de-b595-4be2-8d74-1c917b7a2f28" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("eb9106de-b595-4be2-8d74-1c917b7a2f28")) {                    Plotly.newPlot(                        "eb9106de-b595-4be2-8d74-1c917b7a2f28",                        [{"x":["combination","reference","synthesizing","observation","integration","indistinguishable","production","atmospheric","performance","whiteness","differently","synthesizes","descriptor","represents","applications","challenging","directional","predicting","exemplars","configuration","progressively","connections","interactively","stability","scattering","characteristic","technique","transport","efficiently","hierarchical","diffusion","rendering","coefficients","implementation","simulating","distribution","classifier","classification","transformation","mechanism","multilayer","classifiers","computation","separately","geometric","downstream","parameters","variables","recognition","competitive","challenge","variations","optimizing","deformable","framework","perceptrons","introduced","transformations","instantiation","alternates","discussed","maintenance","heuristics","addresses","limitations","fundamental","resolving","developed","reformulates","uncertainty","effective","deterministic","morphologically","introduce","inflectional","translation","vocabulary","obtaining","phenomena","information","morphological","improvements","generation","inflection","improvement","languages","scenarios","generalization","furthermore","broadcast","segmentation","extracted","evaluation","topically","combining","reduction","knowledge","automatically","integrating","waveforms","significant","automatic","recognizer","probabilistic","assumption","unsupervised","parameter","recommender","inflexible","correlation","including","clustering","approaches","experiments","maintaining","dependent","nonparametric","specified","flexibility","comparing","corresponding","respective","appropriate","dimension","typically","processes","factorization","consequence","correlated","optimized","bivariate","factorize","nonnegative","synthetic","dimensionality","associated","traditional","formalized","comparison","difficult","constantly","intuitively","techniques","numerical","available","throughout","propagation","benchmark","importance","describing","supervised","algorithm","therefore","effectively","necessarily","formalism","definition","advantages","experimentation","application","especially","remaining","iteratively","practical","extensions","summarization","representation","overfitting","monocular","algorithms","overcomplete","dictionaries","unreliable","activities","estimation","experimental","estimates","posterior","simultaneously","dictionary","auxiliary","constrained","specifically","autoencoders","variational","unlabeled","disentangling","representations","processing","demonstrate","literature","disentanglement","positively","experimentally","direction","variation","contribute","generalized","piecewise","tibshirani","complexity","dimensional","instances","formulated","maximizing","difference","different","accelerated","iterative","significantly","minimization","efficiency","effectiveness","maximization","outperforms","optimization","expectation","alignment","disambiguation","citations","graphical","organization","components","canonical","biomedical","interface","extraction","normalization","connected","associating","normalizing","particular","organizations","analyzing","precision","potentially","normalized","extracting","improving","correcting","augmenting","assessment","implements","engineering","popularity","enhancements","diagnosis","exception","industrial","methodologies","monitoring","contributions","inst ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	composers
# 	lojasiewicz
# 	transparency
# 	forthcoming
# 	distilling
# 	disconnected
# 	capitalizing
# 	injecting
# 	preselected
# 	factorial
# 	semiparametric
# 	nonparanormal
# 	discharge
# 	parsimony
# 	magnetoencephalographic
# 	sequentialized
# 	ultrametric
# 	parameterize
# 	econometrics
# 	safeguard
# Some words which never appear in Statistics papers:
# 	morphologically
# 	inflectional
# 	inflection
# 	topically
# 	recognizer
# 	constantly
# 	monocular
# 	disambiguation
# 	citations
# 	associating
# 	traversing
# 	accordance
# 	attractiveness
# 	integrity
# 	mammogram
# 	worldwide
# 	calcifications
# 	radiologists
# 	mammography
# 	localizing

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0729518775735975e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7458333333333333
